# %%
#list comprehension->快速建立list
[f'{num}號' for num in range(1,51)]

# %%
import numpy as np
import pandas as pd
array_2d = np.random.randint(50,100,size=(50,5))
df1 = pd.DataFrame(array_2d,
             columns=['國文','英文','數學','地理','社會'],
             index = [f'{num}號' for num in range(1,51)]
             )
df1
# Out:
#      國文  英文  數學  地理  社會
# 1號   81  76  77  99  93
# 2號   94  91  76  86  86
# 3號   64  53  88  53  84
# 4號   84  60  86  89  87
# 5號   70  91  85  99  62
# 6號   54  93  64  83  69
# 7號   53  70  80  54  50
# 8號   72  51  73  73  74
# 9號   53  79  67  82  95
# 10號  54  87  89  72  71
# 11號  87  60  90  67  68
# 12號  50  87  59  54  91
# 13號  80  72  57  73  69
# 14號  95  56  59  63  82
# 15號  67  68  81  55  92
# 16號  99  79  86  90  76
# 17號  99  59  82  57  67
# 18號  62  88  99  77  60
# 19號  80  54  53  50  88
# 20號  84  79  78  68  63
# 21號  98  54  82  59  66
# 22號  98  51  98  77  74
# 23號  66  92  95  67  89
# 24號  82  85  82  98  60
# 25號  90  79  99  98  60
# 26號  67  69  94  99  72
# 27號  85  73  95  61  82
# 28號  53  79  69  77  62
# 29號  90  70  64  91  75
# 30號  63  83  87  85  81
# 31號  56  50  84  85  82
# 32號  78  63  60  63  99
# 33號  61  93  51  89  79
# 34號  58  72  83  53  50
# 35號  95  82  60  80  71
# 36號  89  61  87  66  96
# 37號  83  96  60  86  54
# 38號  59  57  95  97  70
# 39號  57  52  95  84  96
# 40號  78  52  71  65  80
# 41號  94  87  51  71  82
# 42號  75  81  57  56  94
# 43號  80  83  71  73  97
# 44號  60  61  63  65  97
# 45號  75  57  50  96  84
# 46號  97  75  96  67  64
# 47號  94  75  57  72  52
# 48號  65  52  78  68  57
# 49號  93  75  94  87  82
# 50號  54  76  97  59  60

# %%
#從dataFrame取出ndarray
df1.values

# %%
#dataFrame[欄位名稱] subscript
df1['國文'], df1['英文']
# Out:
# (1號     81
#  2號     94
#  3號     64
#  4號     84
#  5號     70
#  6號     54
#  7號     53
#  8號     72
#  9號     53
#  10號    54
#  11號    87
#  12號    50
#  13號    80
#  14號    95
#  15號    67
#  16號    99
#  17號    99
#  18號    62
#  19號    80
#  20號    84
#  21號    98
#  22號    98
#  23號    66
#  24號    82
#  25號    90
#  26號    67
#  27號    85
#  28號    53
#  29號    90
#  30號    63
#  31號    56
#  32號    78
#  33號    61
#  34號    58
#  35號    95
#  36號    89
#  37號    83
#  38號    59
#  39號    57
#  40號    78
#  41號    94
#  42號    75
#  43號    80
#  44號    60
#  45號    75
#  46號    97
#  47號    94
#  48號    65
#  49號    93
#  50號    54
#  Name: 國文, dtype: int64,
#  1號     76
#  2號     91
#  3號     53
#  4號     60
#  5號     91
#  6號     93
#  7號     70
#  8號     51
#  9號     79
#  10號    87
#  11號    60
#  12號    87
#  13號    72
#  14號    56
#  15號    68
#  16號    79
#  17號    59
#  18號    88
#  19號    54
#  20號    79
#  21號    54
#  22號    51
#  23號    92
#  24號    85
#  25號    79
#  26號    69
#  27號    73
#  28號    79
#  29號    70
#  30號    83
#  31號    50
#  32號    63
#  33號    93
#  34號    72
#  35號    82
#  36號    61
#  37號    96
#  38號    57
#  39號    52
#  40號    52
#  41號    87
#  42號    81
#  43號    83
#  44號    61
#  45號    57
#  46號    75
#  47號    75
#  48號    52
#  49號    75
#  50號    76
#  Name: 英文, dtype: int64)

# %%
#Series的選取,使用subscript
#Series[數值的index]
df1['國文'][0]
#Series[數值的slice]
df1['國文'][:5]
#Series[字串的index]
df1['國文']['1號']
#Series[[字串,字串,字串]]
df1['國文'][['1號','2號','3號']]
# Out:
# /tmp/ipykernel_32922/3448787725.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df1['國文'][0]
# 1號    81
# 2號    94
# 3號    64
# Name: 國文, dtype: int64

# %%
#dataFrame的subscripts
#dataFrame[欄位名稱]
df1['國文']

# %%
#dataFrame的subscripts
#dataFrame[[欄位名稱,欄位名稱]]
df1[['國文','英文']]

# %%
#dataFrame的列的選取
#loc[字串]
#iloc[數值]

# %%
#選取1號
#loc[字串]
df1.loc['1號']
# Out:
# 國文    81
# 英文    76
# 數學    77
# 地理    99
# 社會    93
# Name: 1號, dtype: int64

# %%
#選取1號,2號,3號
#loc[[字串,字串]]
df1.loc[['1號','2號','3號']]
# Out:
#     國文  英文  數學  地理  社會
# 1號  81  76  77  99  93
# 2號  94  91  76  86  86
# 3號  64  53  88  53  84

# %%
#選取前5位
#iloc[index:index]
df1.iloc[:5]
# Out:
#     國文  英文  數學  地理  社會
# 1號  81  76  77  99  93
# 2號  94  91  76  86  86
# 3號  64  53  88  53  84
# 4號  84  60  86  89  87
# 5號  70  91  85  99  62

# %%
#選取後5位
#iloc[數值索引:數值索引]
df1.iloc[-5:]
# Out:
#      國文  英文  數學  地理  社會
# 46號  97  75  96  67  64
# 47號  94  75  57  72  52
# 48號  65  52  78  68  57
# 49號  93  75  94  87  82
# 50號  54  76  97  59  60
